# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ## GRAFICO DE PUNTOS

# %%
#Corrección del estado aleatorio para la reproducibilidad
np.random.seed(19680801)

N=100
x=0.9*np.random.rand(N)
y=0.9*np.random.rand(N)

plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## GRAFICO DE BARRAS

# %%
y_2=[66386,174296,75131,577908,32015]
x_2=["OF1","OF2","OF3","OF4","OF5"]
plt.bar(x_2,y_2)
plt.title("VENTAS ANUALES")
plt.xlabel("Oficina")
plt.ylabel("Ventas en Bs")
plt.show()

# %% [markdown]
# ## Grafico de lineas

# %%
plt.plot([1,2,3,4,5])
plt.xlabel("Algunos numeros")
plt.show()

# %% [markdown]
# ## Series de tiempo

# %%
dates=["2020-may-20","2020-may-21","2020-may-22","2020-may-23","2020-may-24","2020-may-25","2020-may-26"]
x=[datetime.strptime(date, "%Y-%b-%d").date() for date in dates]
y=[20,30,35,18,24,28,26]

plt.plot(x,y,marker="o")
plt.gcf().set_size_inches(9, 7)
plt.show()
